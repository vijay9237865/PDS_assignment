# %% [markdown]
# ## Stage 1: Data collection and reading

# %%
#importing required libraries
import pandas as pd

# %%
#reading data using pandas
data = pd.read_csv("/content/PDS - Sheet1.csv")

# %%
data
# Out:
#    Height  Weight   Age  Grip Frailty
# 0   65.80     112    30    30       N
# 1   71.50     136    19    31       N
# 2   69.40     153    45    29       N
# 3   68.20     142    22    28       Y
# 4   67.80     144    29    24       Y
# 5   68.70     123    50    26       N
# 6   69.80     141    51    22       Y
# 7   70.10     136    23    20       Y
# 8   67.90     112    17    19       N
# 9   66.80     120    19    31       N

# %% [markdown]
# ## Stage 2: Data Cleaning

# %%
# gettinf dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Heights (Inches)  10 non-null     float64
#  1   Weight (Pounds)   10 non-null     int64
#  2    Age              10 non-null     int64
#  3   Grip Strength     10 non-null     int64
#  4   Frailty           10 non-null     object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# ## Stage 3: Data Visualization

# %%
#importing required libraries
import os
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.options.display.float_format = '{:.2f}'.format

# %%
# plotting the weight graph 
plt.figure(figsize=(14,5))
sns.violinplot(data=data, x="Weight",color='#3BA9A9')
plt.show()

# %%
#plotting grip strength frequency graph
plt.figure(figsize=(14,5))
sns.violinplot(data=data , x="Grip",color='beige')
plt.show()

# %%
#visual representation of all possible  relations

info= sns.pairplot(data, height=3,
                            vars=['Height','Weight','Grip'], hue='Frailty', palette="Paired")
plt.show(info)
